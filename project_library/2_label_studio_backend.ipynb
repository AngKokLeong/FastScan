# %% [markdown]
# ### Modify the current command prompt system to Powershell

# %% [markdown]
# Reference: https://discourse.jupyter.org/t/running-powershell-commands-through-jupyter/11238

# %%
import os
os.environ.update(comspec="powershell.exe")

# %% [markdown]
# ### Clone the Git Repository for Label Studio ML Backend

# %%
# !git clone https://github.com/HumanSignal/label-studio-ml-backend.git
# Out:
# Cloning into 'label-studio-ml-backend'...

# %% [markdown]
# ### List the current directories

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D6C3-7406
#
#  Directory of c:\Users\angko\Desktop\CV-Capstone\image_labeller
#
# 25/01/2025  06:47 pm    <DIR>          .
# 24/01/2025  01:51 pm    <DIR>          ..
# 25/01/2025  06:30 pm                 0 1_label_studio_program.ipynb
# 25/01/2025  06:46 pm             1,699 2_label_studio_backend.ipynb
# 25/01/2025  06:44 pm    <DIR>          label-studio-ml-backend
#                2 File(s)          1,699 bytes
#                3 Dir(s)  727,606,611,968 bytes free

# %% [markdown]
# ### Print current directory

# %%
! $PWD
# Out:
# Path
# ----
# C:\Users\angko\Desktop\CV-Capstone\image_labeller

# %% [markdown]
# ### Setting up Grounding DINO Backend Integration with SAM Enabled

# %% [markdown]
# Reference: https://labelstud.io/tutorials/grounding_sam#Using-GPU
#
# Locate this file path C:\Users\angko\Desktop\CV-Capstone\image_labeller\label-studio-ml-backend\label_studio_ml\examples\grounding_sam
#
# Modify the configuration in docker-compose.yml
#
# - LABEL_STUDIO_HOST=http://127.0.0.1:8080
# - LABEL_STUDIO_ACCESS_TOKEN=4545514101c7efca4929f8ae30c932e9b758ebe3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Execute docker compose up in the powershell

# %% [markdown]
# ### Setup the Label Studio Project

# %% [markdown]
# Reference: https://labelstud.io/tutorials/grounding_sam#Grounding-DINO-backend-integration-with-SAM-enabled
